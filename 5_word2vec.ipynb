# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'as', 'originated', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed, train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
# %%time
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.141557
# Nearest to use: fill, issuing, bald, messiah, cleavage, tuned, handkerchief, uncharacteristically,
# Nearest to some: armando, drops, signature, trafficking, porpoise, awoke, scars, nationality,
# Nearest to from: hinton, heijenoort, bop, ovarian, rumours, neurobiology, unproductive, tanned,
# Nearest to known: instinctively, vig, squire, juxtaposition, pyramidal, accessed, allege, texts,
# Nearest to on: proofing, locale, emigr, steelers, denis, excise, removal, queuing,
# Nearest to between: haber, amoeboids, world, billion, tetum, parting, yes, vr,
# Nearest to not: progressives, original, paragliding, gast, fusiliers, osprey, discriminated, parasites,
# Nearest to UNK: creationists, herrera, jerusalem, solidly, salic, hatfield, sepsis, oncoming,
# Nearest to during: thunderstorm, snows, courage, humus, heckman, comets, symbolism, kriol,
# Nearest to and: rifts, kerr, ebro, suborbital, dischord, turnpike, powerpc, multidimensional,
# Nearest to be: turin, unintelligible, chevalier, conveyed, channel, corba, malaya, immanence,
# Nearest to been: remaining, hundred, claudius, weakened, streaks, melodrama, nouveaux, laozi,
# Nearest to if: approbation, gandhara, protestant, finely, neo, younger, postgresql, lameness,
# Nearest to years: positioned, liberalize, tuva, esotericism, editorship, pas, aragon, roy,
# Nearest to b: arnauld, malts, coquitlam, confectionery, erica, wrong, succeeds, clusters,
# Nearest to four: denny, janet, linen, bare, adder, hohenzollern, wayward, rationalization,
# Average loss at step 2000: 4.236126
# Average loss at step 4000: 3.809539
# Average loss at step 6000: 3.706471
# Average loss at step 8000: 3.637499
# Average loss at step 10000: 3.649860
# Nearest to use: uncharacteristically, issuing, fill, messiah, shuffled, bald, terminology, tapestry,
# Nearest to some: many, recognizing, his, crest, match, corrode, armando, kemal,
# Nearest to from: hinton, for, in, balochistan, after, injurious, hartley, rumours,
# Nearest to known: jam, instinctively, texts, such, squire, freikorps, deg, juxtaposition,
# Nearest to on: in, explication, during, paton, at, with, fx, under,
# Nearest to between: with, yes, haber, stiller, krause, austen, km, billion,
# Nearest to not: rl, there, able, to, kov, finds, skillfully, gast,
# Nearest to UNK: ethos, exterior, tendon, bono, goren, flanders, testimonies, mothra,
# Nearest to during: first, at, comets, after, on, in, snows, thunderstorm,
# Nearest to and: of, or, who, ruhollah, acls, tribulations, with, by,
# Nearest to be: have, is, according, by, was, not, extinct, mulberry,
# Nearest to been: was, less, were, previously, claudius, antiparticles, also, slanted,
# Nearest to if: approbation, gandhara, anticipating, leq, younger, un, donne, redistributed,
# Nearest to years: tuva, adjusting, abortion, liberalize, positioned, nominating, tubulin, kde,
# Nearest to b: dugout, abnormalities, clusters, arnauld, confectionery, d, milosevic, malts,
# Nearest to four: three, five, eight, six, seven, two, nine, zero,
# Average loss at step 12000: 3.652193
# Average loss at step 14000: 3.615877
# Average loss at step 16000: 3.609875
# Average loss at step 18000: 3.571846
# Average loss at step 20000: 3.358385
# Nearest to use: uncharacteristically, issuing, fill, dimensionless, terminology, hilly, bald, tuned,
# Nearest to some: many, these, all, different, burdened, several, recognizing, dinner,
# Nearest to from: hinton, after, balochistan, into, on, in, rigdon, communions,
# Nearest to known: such, used, well, jam, instinctively, texts, linked, simply,
# Nearest to on: in, during, against, fx, from, paton, merci, upon,
# Nearest to between: with, yes, km, krause, from, stiller, jer, haber,
# Nearest to not: able, they, rl, we, often, finds, there, be,
# Nearest to UNK: frequently, presbyterian, wait, samoa, goren, de, striking, caesars,
# Nearest to during: on, after, in, although, rigdon, edie, at, first,
# Nearest to and: or, but, in, borland, metternich, minute, delia, including,
# Nearest to be: have, been, was, were, by, observatory, become, according,
# Nearest to been: was, be, previously, less, become, had, were, by,
# Nearest to if: approbation, redistributed, decentralisation, micrometre, gne, leq, curator, madhu,
# Nearest to years: tuva, months, times, abortion, adjusting, year, fini, liberalize,
# Nearest to b: d, dugout, abnormalities, unionists, coquitlam, clusters, confectionery, malts,
# Nearest to four: three, six, eight, five, seven, nine, zero, two,
# Average loss at step 22000: 3.523007
# Average loss at step 24000: 3.512619
# Average loss at step 26000: 3.480961
# Average loss at step 28000: 3.482101
# Average loss at step 30000: 3.547026
# Nearest to use: hilly, dimensionless, terminology, uncharacteristically, name, fill, tapestry, banker,
# Nearest to some: many, these, several, all, different, their, recognizing, tens,
# Nearest to from: into, between, after, hinton, through, balochistan, in, beyond,
# Nearest to known: used, such, well, possible, available, described, jam, kane,
# Nearest to on: during, at, in, upon, over, around, arianism, uncodified,
# Nearest to between: with, from, in, krause, seagull, appended, yes, manx,
# Nearest to not: able, timothy, often, still, never, always, it, now,
# Nearest to UNK: rationalists, tachi, codons, stjepan, http, tomography, module, brotherhoods,
# Nearest to during: after, in, at, on, edie, when, within, rigdon,
# Nearest to and: or, but, including, although, of, which, who, whose,
# Nearest to be: have, been, were, was, are, is, clinch, become,
# Nearest to been: be, become, was, previously, by, were, had, claudius,
# Nearest to if: approbation, when, decentralisation, redistributed, madhu, curator, flutter, deliberations,
# Nearest to years: months, tuva, days, times, year, decades, liberalize, adjusting,
# Nearest to b: abnormalities, d, cosmos, mutant, negligible, answered, ganglia, utah,
# Nearest to four: six, five, three, eight, seven, two, nine, zero,
# Average loss at step 32000: 3.436303
# Average loss at step 34000: 3.521736
# Average loss at step 36000: 3.206803
# Average loss at step 38000: 3.229221
# Average loss at step 40000: 3.404028
# Nearest to use: terminology, all, scarecrow, dimensionless, result, tequila, hilly, sacrifices,
# Nearest to some: many, these, several, all, their, different, most, any,
# Nearest to from: into, through, rigdon, hinton, in, balochistan, illnesses, after,
# Nearest to known: used, such, described, well, possible, regarded, kane, referred,
# Nearest to on: upon, during, in, around, hex, fx, at, normand,
# Nearest to between: with, alarming, manx, within, from, marched, jer, defends,
# Nearest to not: almost, often, never, it, still, timothy, patiently, uml,
# Nearest to UNK: alexanderplatz, cognitive, anxieties, emilio, electorate, testimonies, gracie, wherever,
# Nearest to during: after, at, in, within, on, although, larynx, when,
# Nearest to and: or, including, but, like, as, repackaged, which, while,
# Nearest to be: been, have, were, is, become, according, was, unofficially,
# Nearest to been: be, become, was, previously, were, had, toole, reactor,
# Nearest to if: when, though, approbation, tyrell, does, madhu, statutes, can,
# Nearest to years: months, year, times, decades, days, tuva, adjusting, hours,
# Nearest to b: d, abnormalities, desirable, epicenter, dugout, glyn, supersymmetric, robert,
# Nearest to four: seven, five, three, eight, six, nine, zero, two,
# Average loss at step 42000: 3.391075
# Average loss at step 44000: 3.333767
# Average loss at step 46000: 3.449421
# Average loss at step 48000: 3.445267
# Average loss at step 50000: 3.339146
# Nearest to use: result, hilly, toppled, terminology, sense, uncharacteristically, banker, study,
# Nearest to some: many, these, several, unilateral, all, the, their, various,
# Nearest to from: into, through, balochistan, after, before, hinton, during, hlich,
# Nearest to known: used, such, described, regarded, defined, well, serve, available,
# Nearest to on: during, upon, at, in, around, within, errata, paton,
# Nearest to between: with, in, alarming, within, stuffing, across, until, manx,
# Nearest to not: never, almost, uml, still, patiently, often, always, clearly,
# Nearest to UNK: musique, wolves, monster, agrigentum, brotherhoods, rapper, tipping, joaquin,
# Nearest to during: after, at, in, on, within, when, before, cia,
# Nearest to and: or, but, including, like, which, repackaged, stereotypically, stockpiling,
# Nearest to be: been, were, have, become, are, was, being, survive,
# Nearest to been: become, be, were, was, previously, had, being, recently,
# Nearest to if: when, although, does, before, though, unless, approbation, where,
# Nearest to years: decades, months, days, times, year, tuva, untrained, centuries,
# Nearest to b: d, complexities, antithesis, dunkeld, lachlan, german, epicenter, desirable,
# Nearest to four: seven, eight, five, six, three, nine, two, zero,
# Average loss at step 52000: 3.280037
# Average loss at step 54000: 3.386925
# Average loss at step 56000: 3.449074
# Average loss at step 58000: 3.457385
# Average loss at step 60000: 3.401475
# Nearest to use: result, hilly, toppled, sense, study, uncharacteristically, humanoid, terminology,
# Nearest to some: many, several, these, all, any, those, most, various,
# Nearest to from: through, into, balochistan, hinton, hlich, during, in, including,
# Nearest to known: used, described, such, regarded, possible, defined, serve, available,
# Nearest to on: upon, during, errata, including, through, at, normand, in,
# Nearest to between: with, within, in, alarming, across, among, from, appended,
# Nearest to not: often, patiently, never, still, almost, chosen, clearly, skillfully,
# Nearest to UNK: la, jean, toltec, dominica, handles, leo, j, l,
# Nearest to during: in, after, at, under, on, within, when, until,
# Nearest to and: or, but, pereira, severe, including, ruhollah, lb, coughlin,
# Nearest to be: been, was, have, become, being, is, were, unofficially,
# Nearest to been: be, become, previously, was, had, already, recently, being,
# Nearest to if: when, though, although, before, could, until, does, where,
# Nearest to years: days, decades, months, year, times, centuries, tuva, hours,
# Nearest to b: d, lachlan, antithesis, blames, precambrian, esv, desirable, weighting,
# Nearest to four: seven, five, eight, nine, six, three, two, zero,
# Average loss at step 62000: 3.352178
# Average loss at step 64000: 3.392805
# Average loss at step 66000: 3.373647
# Average loss at step 68000: 3.279571
# Average loss at step 70000: 3.371490
# Nearest to use: study, hilly, humanoid, guatemala, most, result, banker, toppled,
# Nearest to some: many, several, these, various, any, their, the, both,
# Nearest to from: through, hinton, into, after, illnesses, in, rigdon, fisa,
# Nearest to known: used, possible, described, such, defined, regarded, available, referred,
# Nearest to on: upon, errata, during, within, epistemological, under, woodbridge, overall,
# Nearest to between: with, among, within, alarming, across, from, spiked, stuffing,
# Nearest to not: now, still, they, almost, often, kish, also, never,
# Nearest to UNK: woolfson, frances, samson, senatus, caveat, slick, oj, bonhomme,
# Nearest to during: after, in, before, at, within, when, until, since,
# Nearest to and: or, but, however, although, of, who, publicacion, dumplings,
# Nearest to be: been, become, have, is, was, being, prior, odore,
# Nearest to been: become, be, previously, was, recently, were, had, already,
# Nearest to if: when, though, where, before, does, since, until, do,
# Nearest to years: days, decades, months, times, year, centuries, weeks, minutes,
# Nearest to b: d, antithesis, immunodeficiency, lachlan, desirable, p, sasl, glyn,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Average loss at step 72000: 3.378070
# Average loss at step 74000: 3.199544
# Average loss at step 76000: 3.251655
# Average loss at step 78000: 3.342246
# Average loss at step 80000: 3.340826
# Nearest to use: study, most, humanoid, hilly, result, sense, destruction, guatemala,
# Nearest to some: many, several, these, any, various, all, their, mappings,
# Nearest to from: through, into, after, hinton, balochistan, pid, towards, elisabeth,
# Nearest to known: used, possible, described, regarded, such, defined, available, responsible,
# Nearest to on: upon, during, in, within, through, errata, hex, around,
# Nearest to between: with, within, across, among, alarming, ton, spiked, around,
# Nearest to not: still, never, nor, clearly, now, kish, usually, almost,
# Nearest to UNK: uprisings, eschatological, leucippus, bureaucrat, radiance, sterreich, baruch, jaian,
# Nearest to during: after, when, in, before, under, on, until, at,
# Nearest to and: or, but, including, in, lagged, crony, however, earthly,
# Nearest to be: been, being, become, have, was, fail, were, is,
# Nearest to been: become, be, previously, was, being, already, recently, were,
# Nearest to if: when, though, where, before, since, does, is, until,
# Nearest to years: days, months, decades, times, year, weeks, minutes, hours,
# Nearest to b: d, antithesis, desirable, lachlan, finnic, blames, esv, norwood,
# Nearest to four: six, five, eight, seven, three, two, nine, zero,
# Average loss at step 82000: 3.315813
# Average loss at step 84000: 3.313106
# Average loss at step 86000: 3.363297
# Average loss at step 88000: 3.365946
# Average loss at step 90000: 3.354495
# Nearest to use: study, humanoid, guatemala, sense, hilly, rnzaf, banker, result,
# Nearest to some: many, several, these, various, both, their, all, recognizing,
# Nearest to from: through, into, balochistan, after, in, hinton, before, including,
# Nearest to known: used, regarded, described, such, possible, defined, responsible, portrayed,
# Nearest to on: upon, in, errata, epistemological, through, within, during, around,
# Nearest to between: with, among, across, within, alarming, in, jolley, uncovering,
# Nearest to not: still, clearly, never, nor, now, methylene, generally, almost,
# Nearest to UNK: co, webber, bull, prescriptive, amx, caso, image, employing,
# Nearest to during: after, in, when, before, at, within, under, until,
# Nearest to and: or, but, including, golem, in, via, beaconsfield, although,
# Nearest to be: been, have, was, being, become, is, are, odore,
# Nearest to been: become, be, previously, already, was, were, being, recently,
# Nearest to if: when, where, though, before, since, although, follows, implies,
# Nearest to years: days, months, decades, year, times, weeks, hours, centuries,
# Nearest to b: d, antithesis, c, esv, lachlan, distanced, blames, prevails,
# Nearest to four: five, six, eight, seven, three, two, nine, zero,
# Average loss at step 92000: 3.356736
# Average loss at step 94000: 3.341267
# Average loss at step 96000: 3.130710
# Average loss at step 98000: 3.316111
# Average loss at step 100000: 3.362408
# Nearest to use: sense, consider, humanoid, study, result, toppled, rnzaf, throwing,
# Nearest to some: many, several, these, various, mappings, certain, both, preregular,
# Nearest to from: through, in, into, of, pid, aloft, for, hinton,
# Nearest to known: used, regarded, possible, described, available, such, defined, portrayed,
# Nearest to on: upon, during, in, undecided, epistemological, at, theodoret, upgrading,
# Nearest to between: among, across, with, within, alarming, until, through, in,
# Nearest to not: never, nor, still, clearly, now, usually, false, quite,
# Nearest to UNK: martha, lizards, theta, conjugation, titled, wait, lorenzo, confidentiality,
# Nearest to during: after, in, at, on, through, before, when, under,
# Nearest to and: or, but, including, whose, personhood, like, laurentiis, loti,
# Nearest to be: been, being, become, have, fail, is, kinase, were,
# Nearest to been: become, be, was, already, previously, being, were, remained,
# Nearest to if: when, where, though, before, then, although, does, recognize,
# Nearest to years: days, months, decades, times, hours, weeks, centuries, minutes,
# Nearest to b: d, p, c, r, f, n, esv, x,
# Nearest to four: six, five, three, seven, eight, nine, two, zero,
# CPU times: user 17min 48s, sys: 2min 24s, total: 20min 13s
# Wall time: 7min 41s

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
len(words)
# Out:
# 400

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size,num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size,1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  for i in range(batch_size):
    target = skip_window  # target label at the center of the buffer
    cbow = [j for j in range(span) if j is not target]
    batch[i,:] = [buffer[j] for j in cbow]
    labels[i,0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:10]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    for li,row in enumerate(batch):
        print('    batch:', [reverse_dictionary[bi] for bi in row], '=> ', reverse_dictionary[labels[li,0]])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as'] =>  originated
#     batch: ['originated', 'a'] =>  as
#     batch: ['as', 'term'] =>  a
#     batch: ['a', 'of'] =>  term
#     batch: ['term', 'abuse'] =>  of
#     batch: ['of', 'first'] =>  abuse
#     batch: ['abuse', 'used'] =>  first
#     batch: ['first', 'against'] =>  used
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['anarchism', 'originated', 'a', 'term'] =>  as
#     batch: ['originated', 'as', 'term', 'of'] =>  a
#     batch: ['as', 'a', 'of', 'abuse'] =>  term
#     batch: ['a', 'term', 'abuse', 'first'] =>  of
#     batch: ['term', 'of', 'first', 'used'] =>  abuse
#     batch: ['of', 'abuse', 'used', 'against'] =>  first
#     batch: ['abuse', 'first', 'against', 'early'] =>  used
#     batch: ['first', 'used', 'early', 'working'] =>  against

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,num_skips])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size,1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed_0 = tf.nn.embedding_lookup(embeddings, train_dataset[:,0])
  embed_1 = tf.nn.embedding_lookup(embeddings, train_dataset[:,1])
  embed = embed_0 + embed_1
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed, train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
# %%time
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings_cbow = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.647416
# Nearest to or: sloti, fes, capacities, shook, fantastically, confessor, filtering, cubism,
# Nearest to people: iv, sociological, abrupt, ra, estonians, silla, muskets, imaging,
# Nearest to b: sadat, endanger, plow, scilly, passionate, bacall, esteemed, ifor,
# Nearest to only: rife, infamous, dodger, coterminous, ockham, ministerio, painted, prayers,
# Nearest to will: glove, guinevere, saigon, slav, wanderer, sikhs, nasir, portions,
# Nearest to d: cheka, legitimize, taunus, twig, walid, quay, lasted, equivalents,
# Nearest to but: magda, airbases, imitations, documented, towel, aegeus, quatrain, goldberg,
# Nearest to their: reina, boomerang, reichstag, gourmet, expressionist, hinayana, manama, afghans,
# Nearest to at: ibos, madison, tri, faire, hydride, regrets, minix, arsenate,
# Nearest to state: holyhead, abolitionist, tba, islamism, secession, practising, david, slowed,
# Nearest to often: dreamcast, absolutely, lawrence, moravians, ihra, tailed, herder, anthony,
# Nearest to more: croydon, smf, disquieting, aware, parc, have, wield, equipment,
# Nearest to it: gs, clitoral, miso, fronted, pusan, kemerovo, marriott, whistling,
# Nearest to most: harley, truer, rusty, continent, hetzel, workflow, diagonally, carnage,
# Nearest to two: museums, isometric, uz, cyril, proper, phases, marsupial, janos,
# Nearest to from: prejudice, fidelity, navigable, dion, puritan, keys, grits, heizei,
# Average loss at step 2000: 4.093809
# Average loss at step 4000: 3.567274
# Average loss at step 6000: 3.394445
# Average loss at step 8000: 3.247128
# Average loss at step 10000: 3.182073
# Nearest to or: and, than, elisa, p, igg, pheromones, circulated, alicante,
# Nearest to people: embarked, ra, olympias, abrupt, semicolon, silla, slaves, manichean,
# Nearest to b: d, plow, mcc, quote, feodor, dieting, bach, courageous,
# Nearest to only: coterminous, burdens, cultic, persecution, alleviating, kowalski, scratches, breakout,
# Nearest to will: would, may, can, could, should, saigon, inspect, must,
# Nearest to d: b, legitimize, pornography, aguilera, trumbo, royalties, wittenberg, twig,
# Nearest to but: however, that, which, if, could, vaishnavism, finite, giordano,
# Nearest to their: his, its, her, expressionist, townhouse, zamboanga, the, some,
# Nearest to at: in, keeps, itv, on, berenson, anno, under, taker,
# Nearest to state: figures, dilemma, penultimate, portraiture, politicians, secession, nationality, dehydroepiandrosterone,
# Nearest to often: herder, dreamcast, lawrence, it, shot, yet, they, detachable,
# Nearest to more: most, less, very, turnover, gpo, geist, goldoni, treatment,
# Nearest to it: he, there, this, she, which, they, incendiary, simply,
# Nearest to most: more, walkways, many, gpo, lemma, some, structurally, presupposes,
# Nearest to two: six, four, eight, five, three, nine, seven, zero,
# Nearest to from: into, fidelity, deux, after, within, hindustani, in, puritan,
# Average loss at step 12000: 3.203425
# Average loss at step 14000: 3.156787
# Average loss at step 16000: 3.175926
# Average loss at step 18000: 3.125017
# Average loss at step 20000: 2.987718
# Nearest to or: and, than, surprises, warwick, gigs, elisa, polonia, synclavier,
# Nearest to people: scholars, olympias, embarked, someone, racist, pastoral, ra, mode,
# Nearest to b: d, mcc, plow, quote, palatal, plotline, egyptologists, dieting,
# Nearest to only: coterminous, first, burdens, philly, environmentally, projective, rbis, circulates,
# Nearest to will: would, can, may, could, should, must, might, shall,
# Nearest to d: b, twig, legitimize, sir, daley, royalties, undifferentiated, pornography,
# Nearest to but: however, though, that, see, while, and, it, although,
# Nearest to their: its, his, her, the, some, expressionist, many, our,
# Nearest to at: on, under, in, smoot, anno, aliyah, keeps, individualistic,
# Nearest to state: dilemma, figures, secession, silence, government, winding, candler, levees,
# Nearest to often: sometimes, commonly, generally, still, also, there, typically, widely,
# Nearest to more: less, most, very, larger, scooby, kanji, cryonicists, greater,
# Nearest to it: he, she, this, there, they, but, incendiary, which,
# Nearest to most: more, lemma, many, walkways, kicks, videogame, continent, kitts,
# Nearest to two: six, seven, four, three, five, eight, one, zero,
# Nearest to from: into, hindustani, puritan, through, hairpin, cypress, after, during,
# Average loss at step 22000: 3.076435
# Average loss at step 24000: 3.039862
# Average loss at step 26000: 3.002760
# Average loss at step 28000: 3.032702
# Average loss at step 30000: 3.009954
# Nearest to or: and, than, macbeth, edomites, kaltenbrunner, vespasian, matsui, warwick,
# Nearest to people: scholars, embarked, someone, players, men, soldiers, man, biopolymers,
# Nearest to b: d, baloch, n, f, m, tail, dieting, flamebait,
# Nearest to only: coterminous, always, tique, peanuts, projective, croquet, yugoslavia, usually,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to d: b, legitimize, m, twig, sir, nihon, george, daley,
# Nearest to but: however, and, see, though, although, profiling, synclavier, that,
# Nearest to their: its, his, her, the, my, our, your, some,
# Nearest to at: without, under, sixties, ibos, esc, coincidental, berenson, in,
# Nearest to state: secession, government, winding, states, dilemma, view, figures, city,
# Nearest to often: sometimes, commonly, generally, usually, now, typically, still, also,
# Nearest to more: less, very, most, larger, highly, greater, quite, scooby,
# Nearest to it: he, she, this, there, they, aeneas, still, nnhilde,
# Nearest to most: more, many, some, martini, less, hazing, continent, use,
# Nearest to two: three, four, six, five, nine, eight, seven, one,
# Nearest to from: into, through, after, hindustani, gazelle, puritan, savory, cypress,
# Average loss at step 32000: 2.830050
# Average loss at step 34000: 2.959873
# Average loss at step 36000: 2.949083
# Average loss at step 38000: 2.945699
# Average loss at step 40000: 2.929304
# Nearest to or: and, but, than, while, shevat, fashionable, blindness, macbeth,
# Nearest to people: scholars, men, scientists, fans, women, man, animals, biopolymers,
# Nearest to b: d, n, aragorn, k, baloch, flamebait, f, plotline,
# Nearest to only: always, usually, just, peanuts, helens, scratches, ostend, not,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to d: b, legitimize, nihon, m, twig, marquesas, hubbard, reappear,
# Nearest to but: however, and, while, than, though, although, or, see,
# Nearest to their: its, his, her, my, your, our, the, whose,
# Nearest to at: without, leopold, coincidental, sixties, keeps, eclipse, memex, under,
# Nearest to state: city, dilemma, americium, government, secession, states, gordie, affreightment,
# Nearest to often: sometimes, usually, generally, commonly, typically, also, still, now,
# Nearest to more: less, very, most, quite, larger, highly, scooby, greater,
# Nearest to it: he, she, there, this, multiplan, still, they, nnhilde,
# Nearest to most: more, many, less, some, especially, hazing, tretyakov, martini,
# Nearest to two: three, six, four, five, seven, eight, nine, one,
# Nearest to from: through, into, within, during, rojas, after, historiographical, by,
# Average loss at step 42000: 2.951591
# Average loss at step 44000: 2.959989
# Average loss at step 46000: 2.909208
# Average loss at step 48000: 2.865015
# Average loss at step 50000: 2.851221
# Nearest to or: and, though, than, but, usbc, while, pontius, mythic,
# Nearest to people: children, soldiers, scholars, citizens, women, fans, players, men,
# Nearest to b: d, awacs, bund, tail, demigods, philippa, baloch, blake,
# Nearest to only: always, not, just, either, helens, still, normally, ostend,
# Nearest to will: would, could, may, can, must, might, should, cannot,
# Nearest to d: b, george, candidate, labours, legitimize, micronation, cheka, walid,
# Nearest to but: however, although, though, while, and, or, averted, venereal,
# Nearest to their: its, his, her, your, our, my, the, some,
# Nearest to at: during, in, coincidental, near, on, under, sixties, pathos,
# Nearest to state: government, secession, city, affreightment, states, dilemma, union, americium,
# Nearest to often: sometimes, usually, generally, commonly, now, frequently, typically, widely,
# Nearest to more: less, most, larger, quite, very, highly, greater, extremely,
# Nearest to it: he, she, this, there, they, itself, estas, multiplan,
# Nearest to most: more, many, less, especially, some, all, synth, lubricated,
# Nearest to two: three, four, six, seven, five, eight, nine, one,
# Nearest to from: through, within, into, during, in, snaps, without, before,
# Average loss at step 52000: 2.887068
# Average loss at step 54000: 2.863959
# Average loss at step 56000: 2.857764
# Average loss at step 58000: 2.752265
# Average loss at step 60000: 2.832233
# Nearest to or: than, and, blindness, macbeth, alicante, tert, fortran, norwegians,
# Nearest to people: citizens, men, children, soldiers, fans, scholars, women, man,
# Nearest to b: d, bund, c, h, demigods, k, x, philippa,
# Nearest to only: always, normally, just, actually, usually, generally, either, helens,
# Nearest to will: would, could, must, can, should, may, might, cannot,
# Nearest to d: b, h, george, micronation, chrome, daley, margulis, armas,
# Nearest to but: however, although, and, though, while, voicing, penrose, than,
# Nearest to their: its, his, her, your, our, my, the, whose,
# Nearest to at: in, under, coincidental, near, on, during, ernie, valdemar,
# Nearest to state: states, affreightment, secession, government, federal, union, expired, dilemma,
# Nearest to often: usually, sometimes, commonly, generally, typically, frequently, also, now,
# Nearest to more: less, most, very, larger, quite, greater, highly, longer,
# Nearest to it: she, he, there, itself, they, this, incendiary, alludes,
# Nearest to most: more, less, many, especially, some, use, because, contests,
# Nearest to two: three, four, six, five, one, seven, eight, nine,
# Nearest to from: through, within, into, hindustani, after, during, before, snaps,
# Average loss at step 62000: 2.829592
# Average loss at step 64000: 2.768234
# Average loss at step 66000: 2.765397
# Average loss at step 68000: 2.719568
# Average loss at step 70000: 2.781791
# Nearest to or: and, than, though, shevat, like, warwick, geraldine, blindness,
# Nearest to people: men, women, children, citizens, soldiers, jews, players, man,
# Nearest to b: d, awacs, bund, ut, mislead, transposing, c, clampett,
# Nearest to only: either, always, both, synth, best, coterminous, just, normally,
# Nearest to will: must, would, can, could, may, should, might, cannot,
# Nearest to d: b, physicalism, laos, labours, crept, might, daley, armas,
# Nearest to but: however, although, though, and, that, albumin, she, he,
# Nearest to their: its, his, your, her, our, my, the, whose,
# Nearest to at: sixties, coincidental, under, near, on, memex, ibos, in,
# Nearest to state: government, states, federal, secession, indignation, affreightment, quantity, shin,
# Nearest to often: sometimes, usually, commonly, typically, generally, frequently, widely, now,
# Nearest to more: less, greater, quite, very, most, larger, highly, endangered,
# Nearest to it: she, he, there, they, this, nothing, itself, incendiary,
# Nearest to most: more, less, many, especially, some, particularly, explosively, mattathias,
# Nearest to two: three, four, five, seven, eight, six, one, nine,
# Nearest to from: through, into, within, under, snaps, after, before, during,
# Average loss at step 72000: 2.800368
# Average loss at step 74000: 2.644454
# Average loss at step 76000: 2.807713
# Average loss at step 78000: 2.827639
# Average loss at step 80000: 2.780776
# Nearest to or: and, than, though, alicante, synclavier, yeah, angolan, vapour,
# Nearest to people: men, women, citizens, children, soldiers, jews, man, scholars,
# Nearest to b: d, c, bund, polo, cdot, vesque, beeching, j,
# Nearest to only: either, helens, always, normally, just, ostend, thatched, approximately,
# Nearest to will: would, could, must, can, should, may, might, cannot,
# Nearest to d: b, legitimize, c, labours, micronation, convoys, might, nihon,
# Nearest to but: however, although, and, though, albumin, which, implosion, bottlers,
# Nearest to their: its, his, her, your, our, my, the, whose,
# Nearest to at: coincidental, near, in, sixties, copa, under, anno, around,
# Nearest to state: federal, government, states, boarding, indignation, americium, shin, city,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, traditionally, now,
# Nearest to more: less, very, quite, larger, most, rather, greater, extremely,
# Nearest to it: he, she, there, this, itself, they, today, however,
# Nearest to most: many, more, less, some, particularly, especially, several, earliest,
# Nearest to two: three, four, five, six, eight, one, seven, nine,
# Nearest to from: through, within, during, rojas, across, into, without, snaps,
# Average loss at step 82000: 2.668638
# Average loss at step 84000: 2.768926
# Average loss at step 86000: 2.738504
# Average loss at step 88000: 2.757596
# Average loss at step 90000: 2.733627
# Nearest to or: and, than, chisholm, fta, polonia, shevat, although, resign,
# Nearest to people: women, men, citizens, jews, children, authors, individuals, soldiers,
# Nearest to b: d, bund, c, polo, cdot, clampett, bartholomew, awacs,
# Nearest to only: always, until, either, helens, just, normally, roughly, last,
# Nearest to will: would, should, could, can, must, might, may, cannot,
# Nearest to d: b, lambda, legitimize, micronation, nihon, k, labours, kettering,
# Nearest to but: however, although, though, see, and, bottlers, while, until,
# Nearest to their: its, his, her, our, your, my, whose, the,
# Nearest to at: coincidental, near, in, copa, during, anno, factorizations, stats,
# Nearest to state: dalhousie, national, americium, government, boarding, dilemma, city, federal,
# Nearest to often: usually, sometimes, commonly, typically, generally, frequently, traditionally, now,
# Nearest to more: less, quite, most, larger, very, greater, highly, longer,
# Nearest to it: he, she, this, there, they, itself, bookkeeping, today,
# Nearest to most: more, some, less, many, particularly, especially, critique, because,
# Nearest to two: six, four, three, seven, eight, five, one, nine,
# Nearest to from: through, into, across, during, without, puritan, including, under,
# Average loss at step 92000: 2.675880
# Average loss at step 94000: 2.722403
# Average loss at step 96000: 2.704064
# Average loss at step 98000: 2.366567
# Average loss at step 100000: 2.403171
# Nearest to or: and, than, though, shevat, usbc, musket, traditional, macbeth,
# Nearest to people: women, men, children, citizens, person, individuals, persons, jews,
# Nearest to b: d, unrequited, awacs, decrypted, pepin, shirt, benton, bartholomew,
# Nearest to only: either, until, always, last, helens, thatched, crumble, attains,
# Nearest to will: would, could, must, should, can, might, may, cannot,
# Nearest to d: b, crept, labours, cio, candidate, armas, convoys, reputedly,
# Nearest to but: however, though, although, and, while, until, despite, voicing,
# Nearest to their: its, his, her, your, our, my, whose, the,
# Nearest to at: near, during, in, on, hh, anno, after, copa,
# Nearest to state: states, americium, federal, boarding, national, mercedes, dalhousie, campus,
# Nearest to often: usually, sometimes, commonly, generally, frequently, typically, traditionally, now,
# Nearest to more: less, most, quite, larger, very, rather, too, highly,
# Nearest to it: she, he, there, this, they, probably, incendiary, dissipated,
# Nearest to most: more, less, especially, some, particularly, many, picnic, lemma,
# Nearest to two: three, four, five, six, eight, seven, nine, zero,
# Nearest to from: into, through, rojas, without, via, across, snaps, during,
# CPU times: user 18min 28s, sys: 2min 31s, total: 20min 59s
# Wall time: 7min 22s

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings_cbow[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
